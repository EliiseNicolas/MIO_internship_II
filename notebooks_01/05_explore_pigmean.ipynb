# %%
#-----------  imports
import os
from pathlib import Path
import sys

# data
import numpy as np
import pandas as pd
import xarray as xr
import csv
import netCDF4 as nc

# plots
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import ListedColormap, BoundaryNorm
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.cm as cm
import matplotlib.gridspec as gridspec
import matplotlib.colors as mcolors
import matplotlib.dates as mdates
import cartopy.crs as ccrs 
import cartopy.feature as cfeature
import cmocean

# image processing
from skimage import feature, filters
import cv2

# ML
from skfda.ml.clustering import KMeans
from skfda.representation import FDataGrid
from scipy.stats import gaussian_kde
    
import re
import gc
import pywt
import mat73

from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
path = "/home/mmolinet/Elisou/MIO_internship_partII/data_01/raw/PIGMeANN_daily/MDN_20180101.nc"

# %%
with xr.open_dataset(path) as ds : 
    print(ds)
    # var = list(ds.data_vars)
    # for v in var : 
    #     print(v)
    #     print(ds[v].attrs["comment"])
    # chl = np.nanmean(ds["use_Chla"].values, axis=0)
    # fig, ax = plt.subplots(figsize=(10, 6), subplot_kw={"projection": ccrs.PlateCarree()})
    # ax.add_feature(cfeature.LAND)
    # ax.add_feature(cfeature.COASTLINE)

    # sc = ax.pcolormesh(
    #     ds["lon"].values, ds["lat"].values,
    #     chl,
    #     transform=ccrs.PlateCarree(),
    #     cmap="RdBu_r"
    # )
    # plt.colorbar(sc, ax=ax, label="FPCA score")
    # plt.imshow(chl)
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:           (time: 1, lat: 1681, lon: 8640)
# Coordinates:
#   * time              (time) datetime64[ns] 8B 2018-01-01
#   * lat               (lat) float32 7kB -19.98 -20.02 -20.06 ... -89.94 -89.98
#   * lon               (lon) float32 35kB -180.0 -179.9 -179.9 ... 179.9 180.0
# Data variables: (12/74)
#     c_q50_Chla        (time, lat, lon) float32 58MB ...
#     c_q05_Chla        (time, lat, lon) float32 58MB ...
#     c_q95_Chla        (time, lat, lon) float32 58MB ...
#     c_uncond_Chla     (time, lat, lon) float32 58MB ...
#     c_cond_Chla       (time, lat, lon) float32 58MB ...
#     p_present_Chla    (time, lat, lon) float32 58MB ...
#     ...                ...
#     c_cond_DvChla     (time, lat, lon) float32 58MB ...
#     p_present_DvChla  (time, lat, lon) float32 58MB ...
#     unc_DvChla        (time, lat, lon) float32 58MB ...
#     use_DvChla        (time, lat, lon) float32 58MB ...
# ...
